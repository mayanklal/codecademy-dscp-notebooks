# %%
#Load Required Libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

#For cleaning Strings
import re

pd.set_option('display.max_colwidth', None)

# %%
#Load Dataset
df_jeopardy = pd.read_csv('jeopardy.csv')

#Glimpse of DataFrame
df_jeopardy.head()
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                                                                                       Question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3                         In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4     Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
#
#        Answer
# 0  Copernicus
# 1  Jim Thorpe
# 2     Arizona
# 3  McDonald's
# 4  John Adams

# %%
#Check Key Information about DataFrame
df_jeopardy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216930 entries, 0 to 216929
# Data columns (total 7 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   Show Number  216930 non-null  int64
#  1    Air Date    216930 non-null  object
#  2    Round       216930 non-null  object
#  3    Category    216930 non-null  object
#  4    Value       216930 non-null  object
#  5    Question    216930 non-null  object
#  6    Answer      216928 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 11.6+ MB

# %%
#Clean Column Names
df_jeopardy.columns = ['show_number', 'air_date',
'round', 'category', 'value', 'question', 'answer']

df_jeopardy.head(3)
# Out:
#    show_number    air_date      round                         category value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
#
#                                                                                                       question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
#
#        answer
# 0  Copernicus
# 1  Jim Thorpe
# 2     Arizona

# %%
base = r'^{}'
expr = '(?=.*{})'
words = ['apple', 'banana', 'cat']  # example
base.format(''.join(expr.format(w) for w in words))
# Out:
# '^(?=.*apple\\s)(?=.*banana\\s)(?=.*cat\\s)'

# %%
#Function to return relevant rows in the DataFrame based on the list of Keywords
def relevant_rows(df, list_of_words):
    base = r'^{}'
    expr = '(?=.*{}\s)' #?= Means Positive Lookahead in Regular Expressions. 
    #For more info - https://www.stefanjudis.com/blog/a-regular-expression-lookahead-lookbehind-cheat-sheet/
    pattern = base.format(''.join(expr.format(word) for word in list_of_words)) #Ensure that all words are in the sentence
    print(pattern) # Verify Pattern
    result_df = df[df.question_clean.str.contains(pattern, case = False)] # Make sure that case insensitive matching is being done.
    return result_df

# %%
result = relevant_rows(df_jeopardy, ["India", "Gandhi"])
result
# Out:
#         show_number    air_date             round              category  \
# 42320          1605  1991-07-19         Jeopardy!              RELIGION
# 62306          2948  1997-05-28         Jeopardy!               HISTORY
# 89179          3203  1998-07-01  Double Jeopardy!    ACTORS & ACTRESSES
# 121606         4248  2003-02-05  Double Jeopardy!  GOING, GOING, GANDHI
# 126154         4363  2003-07-16  Double Jeopardy!     ALL IN THE FAMILY
#
#         value  \
# 42320    $500
# 62306    $300
# 89179   $1000
# 121606  $2000
# 126154   $400
#
#                                                                                                question  \
# 42320                                 A religious retreat or commune in India; Gandhi had one at Wardha
# 62306                           In 1942 he replaced Gandhi as leader of India's National Congress Party
# 89179   This "Gandhi" star is the son of an Indian physician who emigrated to England from South Africa
# 121606       While still a teenager, Gandhi left India & traveled to this capital to get his law degree
# 126154                         This was Indira Gandhi's maiden name (her father was India's first P.M.)
#
#               answer
# 42320      an ashram
# 62306          Nehru
# 89179   Ben Kingsley
# 121606        London
# 126154         Nehru

# %%
# Using Regular Expressions to Clean Text
s = "string. With. Punctuation? england's"
s = re.sub(r'[^\w\s]',' ',s)
s = re.sub(' +', ' ', s)
s = s.lower()
s
# Out:
# 'string with punctuation england s'

# %% [markdown]
# **Notes on Regular Expression**
#
# * **Optional Quantifiers** - Denoted by a `?`. Indicates character can appear either `0` or `1` time. `humou?r` will match both `humour` or `humor`.
# * **Character Sets** - Denoted by a `[]`. Match any of the characters included in the brackets. `con[sc]en[sc]us` will match any of the spellings `consensus`, `concensus`, `consencus`, and `concencus`.
# * **Literals** - Match exact set of literals. The regex `monkey` will completely match the text `monkey` but will also match `monkey` in text `The monkeys like to eat bananas`.
# * **Fixed Quantifiers** - Denoted by a `{}`. Matches exact quantity or the quantity range of characters to be matched. The regular expression `roa{3}r` will match the text `roaaar`, while the regular expression `roa{3,6}r` will match `roaaar`, `roaaaar`, `roaaaaar`, or `roaaaaaar`.
# * **Alternation** - Denoted by a `|`. Allows for the matching of either of two subexpressions. The regex `baboons|gorillas` will match the text `baboons` as well as the text `gorillas`.
# * **Anchors** - Anchors (hat  and dollar sign) are used in regular expressions to match text at the start and end of a string.
# * **Wildcards** - Denoted by a `.`. Can match any single character. the regular expression `.........` will match the text orangutan, marsupial, or any other 9-character text.
# * **Kleene** - `*` indicates that the preceding character can occur 0 or more times.  `+` indicates that the preceding character can occur 1 or more times.
# * **Grouping** - Accomplished by open `(` and close parenthesis `)`. Thus the regular expression `I love (baboons|gorillas)` will match the text `I love baboons` as well as `I love gorillas`, as the grouping limits the reach of the `|` to the text within the parentheses.

# %%
#Find Rows where Value is equal to None
df_jeopardy[df_jeopardy.value == 'None']
# Out:
#         show_number    air_date            round  \
# 55             4680  2004-12-31  Final Jeopardy!
# 116            5957  2010-07-06  Final Jeopardy!
# 174            3751  2000-12-18  Final Jeopardy!
# 235            3673  2000-07-19  Final Jeopardy!
# 296            4931  2006-02-06  Final Jeopardy!
# ...             ...         ...              ...
# 216686         3940  2001-10-19  Final Jeopardy!
# 216746         6044  2010-12-16  Final Jeopardy!
# 216807         5070  2006-09-29  Final Jeopardy!
# 216868         5195  2007-03-23  Final Jeopardy!
# 216929         4999  2006-05-11  Final Jeopardy!
#
#                                 category value  \
# 55                      THE SOLAR SYSTEM  None
# 116                       HISTORIC WOMEN  None
# 174                       SPORTS LEGENDS  None
# 235                    THE MAP OF EUROPE  None
# 296                         FAMOUS SHIPS  None
# ...                                  ...   ...
# 216686  MAJOR LEAGUE BASEBALL TEAM NAMES  None
# 216746                       SKYSCRAPERS  None
# 216807                 NATIONAL CAPITALS  None
# 216868               BESTSELLING AUTHORS  None
# 216929                    HISTORIC NAMES  None
#
#                                                                                                                      question  \
# 55                              Objects that pass closer to the sun than Mercury have been named for this mythological figure
# 116                                                      She was born in Virginia around 1596 & died in Kent, England in 1617
# 174     If Joe DiMaggio's hitting streak had gone one more game in 1941, this company would have given him a $10,000 contract
# 235                         Bordering Italy, Austria, Hungary & Croatia, it's one of the world's newest independent countries
# 296                                  On December 27, 1831 it departed Plymouth, England to map the coastline of South America
# ...                                                                                                                       ...
# 216686      This team received its name after an 1890 incident in which it "stole" away an important player from another team
# 216746               After a construction boom fueled by oil & gas money, this capital city now has Europe's tallest building
# 216807                                                      This city's website calls it "the last divided capital in Europe"
# 216868                  He had the year's bestselling novel a record 7 years in a row with 7 different titles, ending in 2000
# 216929                A silent movie title includes the last name of this 18th c. statesman & favorite of Catherine the Great
#
#                                  answer
# 55                               Icarus
# 116                          Pocahontas
# 174     H.J. Heinz (Heinz 57 Varieties)
# 235                            Slovenia
# 296                      the HMS Beagle
# ...                                 ...
# 216686               Pittsburgh Pirates
# 216746                           Moscow
# 216807                          Nicosia
# 216868                     John Grisham
# 216929   Grigori Alexandrovich Potemkin
#
# [3634 rows x 7 columns]

# %%
#Convert None to $0 using loc
df_jeopardy.loc[df_jeopardy.value == 'None', 'value'] = '$0'

# %%
#Convert Dollar String to Float
df_jeopardy['value_float'] = df_jeopardy['value'].replace('[\$,]', '', regex=True).astype(float)
df_jeopardy.head()
# Out:
#    show_number    air_date      round                         category value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY  $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES  $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...  $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE  $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES  $200
#
#                                                                                                       question  \
# 0             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3                         In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4     Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
#
#        answer  value_float
# 0  Copernicus        200.0
# 1  Jim Thorpe        200.0
# 2     Arizona        200.0
# 3  McDonald's        200.0
# 4  John Adams        200.0

# %%
#Clean Question Column
# Replace All Characters except Alphabets and Digits with space.
df_jeopardy['question_clean'] = df_jeopardy['question'].apply(lambda x: re.sub(r'[^\w\s]',' ',x))
# Remove Extra Spaces
df_jeopardy['question_clean'] = df_jeopardy['question_clean'].apply(lambda x: re.sub(' +', ' ',x))
# Change to lower case
df_jeopardy['question_clean'] = df_jeopardy['question_clean'].str.lower()
# Verify Results
df_jeopardy
# Out:
#         show_number    air_date             round  \
# 0              4680  2004-12-31         Jeopardy!
# 1              4680  2004-12-31         Jeopardy!
# 2              4680  2004-12-31         Jeopardy!
# 3              4680  2004-12-31         Jeopardy!
# 4              4680  2004-12-31         Jeopardy!
# ...             ...         ...               ...
# 216925         4999  2006-05-11  Double Jeopardy!
# 216926         4999  2006-05-11  Double Jeopardy!
# 216927         4999  2006-05-11  Double Jeopardy!
# 216928         4999  2006-05-11  Double Jeopardy!
# 216929         4999  2006-05-11   Final Jeopardy!
#
#                                category  value  \
# 0                               HISTORY   $200
# 1       ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2           EVERYBODY TALKS ABOUT IT...   $200
# 3                      THE COMPANY LINE   $200
# 4                   EPITAPHS & TRIBUTES   $200
# ...                                 ...    ...
# 216925                   RIDDLE ME THIS  $2000
# 216926                        "T" BIRDS  $2000
# 216927           AUTHORS IN THEIR YOUTH  $2000
# 216928                       QUOTATIONS  $2000
# 216929                   HISTORIC NAMES     $0
#
#                                                                                                                       question  \
# 0                             For the last 8 years of his life, Galileo was under house arrest for espousing this man's theory
# 1                  No. 2: 1912 Olympian; football star at Carlisle Indian School; 6 MLB seasons with the Reds, Giants & Braves
# 2                                     The city of Yuma in this state has a record average of 4,055 hours of sunshine each year
# 3                                         In 1963, live on "The Art Linkletter Show", this company served its billionth burger
# 4                     Signer of the Dec. of Indep., framer of the Constitution of Mass., second President of the United States
# ...                                                                                                                        ...
# 216925                                              This Puccini opera turns on the solution to 3 riddles posed by the heroine
# 216926                 In North America this term is properly applied to only 4 species that are crested, including the tufted
# 216927               In Penny Lane, where this "Hellraiser" grew up, the barber shaves another customer--then flays him alive!
# 216928  From Ft. Sill, Okla. he made the plea, Arizona is my land, my home, my father's land, to which I now ask to... return"
# 216929                 A silent movie title includes the last name of this 18th c. statesman & favorite of Catherine the Great
#
#                                 answer  value_float  \
# 0                           Copernicus        200.0
# 1                           Jim Thorpe        200.0
# 2                              Arizona        200.0
# 3                           McDonald's        200.0
# 4                           John Adams        200.0
# ...                                ...          ...
# 216925                        Turandot       2000.0
# 216926                      a titmouse       2000.0
# 216927                    Clive Barker       2000.0
# 216928                        Geronimo       2000.0
# 216929  Grigori Alexandrovich Potemkin          0.0
#
#                                                                                                       question_clean
# 0                    for the last 8 years of his life galileo was under house arrest for espousing this man s theory
# 1               no 2 1912 olympian football star at carlisle indian school 6 mlb seasons with the reds giants braves
# 2                           the city of yuma in this state has a record average of 4 055 hours of sunshine each year
# 3                                   in 1963 live on the art linkletter show this company served its billionth burger
# 4                signer of the dec of indep framer of the constitution of mass second president of the united states
# ...                                                                                                              ...
# 216925                                    this puccini opera turns on the solution to 3 riddles posed by the heroine
# 216926        in north america this term is properly applied to only 4 species that are crested including the tufted
# 216927          in penny lane where this hellraiser grew up the barber shaves another customer then flays him alive
# 216928  from ft sill okla he made the plea arizona is my land my home my father s land to which i now ask to return
# 216929          a silent movie title includes the last name of this 18th c statesman favorite of catherine the great
#
# [216930 rows x 9 columns]

# %%
Relevant_Questions = relevant_rows(df_jeopardy, ["Indira","Gandhi"])
Relevant_Questions
# Out:
# ^(?=.*Indira\s)(?=.*Gandhi\s)
#         show_number    air_date             round  \
# 11545          4461  2004-01-19   Final Jeopardy!
# 24869          5271  2007-07-09  Double Jeopardy!
# 56837          4380  2003-09-26  Double Jeopardy!
# 57589          6034  2010-12-02         Jeopardy!
# 92417          3565  2000-02-18         Jeopardy!
# 126154         4363  2003-07-16  Double Jeopardy!
# 165757         4673  2004-12-22         Jeopardy!
# 186628         4277  2003-03-18         Jeopardy!
# 198777         5534  2008-10-02  Double Jeopardy!
#
#                                      category  value  \
# 11545                          RANKS & TITLES     $0
# 24869                            AIR APPARENT  $2000
# 56837                    FORMER WORLD LEADERS   $800
# 57589                          FASHION TRENDS   $600
# 92417                          WORLD CAPITALS   $200
# 126154                      ALL IN THE FAMILY   $400
# 165757                            "N"TICE ME!   $600
# 186628              CAPITAL CITY UNIVERSITIES   $200
# 198777  ELEANOR ROOSEVELT GOES TO THE THEATRE  $1200
#
#                                                                                                                    question  \
# 11545                                     Queen Victoria & Indira Gandhi each held this title, though only one was official
# 24869     1984 news included Indira Gandhi's death, as well as a deadly gas leak at this company's chemical plant in Bhopal
# 56837                                  Indira Gandhi was the first & only female prime minister so far of this Asian nation
# 57589                   The Beatles helped popularize this jacket, the original of which was worn by Indira Gandhi's father
# 92417                                                    Indira Gandhi International Airport lies just outside this capital
# 126154                                             This was Indira Gandhi's maiden name (her father was India's first P.M.)
# 165757                                            When you land at Indira Gandhi International Airport, you're in this city
# 186628                                                                               Indira Gandhi National Open University
# 198777  Eleanor took Indira Gandhi to see this man's play "The Night Of The Iguana"; it left both ladies "a little baffled"
#
#                     answer  value_float  \
# 11545     Empress of India          0.0
# 24869        Union Carbide       2000.0
# 56837                India        800.0
# 57589     the Nehru jacket        600.0
# 92417            New Delhi        200.0
# 126154               Nehru        400.0
# 165757           New Delhi        600.0
# 186628           New Delhi        200.0
# 198777  Tennessee Williams       1200.0
#
#                                                                                                           question_clean
# 11545                                     queen victoria indira gandhi each held this title though only one was official
# 24869   1984 news included indira gandhi s death as well as a deadly gas leak at this company s chemical plant in bhopal
# 56837                                 indira gandhi was the first only female prime minister so far of this asian nation
# 57589                 the beatles helped popularize this jacket the original of which was worn by indira gandhi s father
# 92417                                                 indira gandhi international airport lies just outside this capital
# 126154                                            this was indira gandhi s maiden name her father was india s first p m
# 165757                                          when you land at indira gandhi international airport you re in this city
# 186628                                                                            indira gandhi national open university
# 198777   eleanor took indira gandhi to see this man s play the night of the iguana it left both ladies a little baffled

# %%
#Average Value of Questions with Relevant Keywords
Relevant_Questions.value_float.mean()
# Out:
# 819.5121951219512
